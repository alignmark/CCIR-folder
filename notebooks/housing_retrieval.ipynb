# %% [markdown]
# rental properties in the area

# %%
import googlemaps
import pandas as pd

# Initialize Google Maps client with the Google Maps API key
gmaps = googlemaps.Client(key='AIzaSyDZ4gKWNxnpJOUy9z86CxYFcLhe1yNPHug')

# List of properties with additional data
properties = [
    {"address": "1 Leaside Park Dr 314, Toronto", "beds": 1, "baths": 1, "type": "Condo Apt Apartment", "price": 2350, "area": "700-799"},
    {"address": "160 Vanderhoof Ave 301, Toronto", "beds": "1+1", "baths": 1, "type": "Condo Apt Apartment", "price": 2550, "area": "600-699"},
    {"address": "21 Overlea Blvd #2010, Toronto", "beds": "1+1", "baths": 1, "type": "Condo Apt Apartment", "price": 2700, "area": "800-899"},
    {"address": "725 Don Mills Rd 706, Toronto", "beds": 2, "baths": 1, "type": "Condo Apt Apartment", "price": 2900, "area": "800-899"},
    {"address": "35 Brian Peck Cres 910, Toronto", "beds": 2, "baths": 2, "type": "Condo Apt Apartment", "price": 2950, "area": "700-799"},
    {"address": "35 Brian Peck Cres 723, Toronto", "beds": 2, "baths": 2, "type": "Condo Apt Apartment", "price": 2995, "area": "800-899"},
    {"address": "35 Brian Peck Cres 1405, Toronto", "beds": "2+1", "baths": 2, "type": "Condo Apt Apartment", "price": 3000, "area": "800-899"},
    {"address": "35 Brian Peck Cres Lph23, Toronto", "beds": 2, "baths": 2, "type": "Condo Apt Apartment", "price": 3100, "area": "800-899"},
    {"address": "11 Thorncliffe Pk Dr 914, Toronto", "beds": 2, "baths": 2, "type": "Condo Apt Apartment", "price": 3200, "area": "900-999"},
    {"address": "6 Brian Peck Cres 101, Toronto", "beds": 2, "baths": 2, "type": "Condo Townhouse Stacked Townhse", "price": 3400, "area": "900-999"},
    {"address": "37 Wolverton Ave, Toronto", "beds": "2+1", "baths": 2, "type": "Detached Bungalow", "price": 3600, "area": None}  # Detached Bungalow with no area specified
]

# Function to get latitude and longitude using Google Maps Geocoding API
def geocode_address(address):
    geocode_result = gmaps.geocode(address)
    if geocode_result:
        location = geocode_result[0]['geometry']['location']
        return location['lat'], location['lng']
    else:
        return None, None

# Create a list to store property data with coordinates
property_data = []

for property in properties:
    print(f"Geocoding address: {property['address']}")
    lat, lng = geocode_address(property['address'])
    property['latitude'] = lat
    property['longitude'] = lng
    property_data.append(property)

# Create a DataFrame from the property data
housing_df = pd.DataFrame(property_data)

# Reorder the columns for better readability
housing_df = housing_df[['address', 'latitude', 'longitude', 'beds', 'baths', 'type', 'price', 'area']]

# Save the DataFrame to a CSV file
housing_df.to_csv('../data/processed/housing_rental.csv', index=False)
print("Housing data saved to ../data/processed/housing_rental.csv")
# Out:
# Geocoding address: 1 Leaside Park Dr 314, Toronto
# Geocoding address: 160 Vanderhoof Ave 301, Toronto
# Geocoding address: 21 Overlea Blvd #2010, Toronto
# Geocoding address: 725 Don Mills Rd 706, Toronto
# Geocoding address: 35 Brian Peck Cres 910, Toronto
# Geocoding address: 35 Brian Peck Cres 723, Toronto
# Geocoding address: 35 Brian Peck Cres 1405, Toronto
# Geocoding address: 35 Brian Peck Cres Lph23, Toronto
# Geocoding address: 11 Thorncliffe Pk Dr 914, Toronto
# Geocoding address: 6 Brian Peck Cres 101, Toronto
# Geocoding address: 37 Wolverton Ave, Toronto
# Housing data saved to ../data/processed/housing_rental.csv

# %% [markdown]
# properties for sale in the area

# %%
import googlemaps
import pandas as pd

# Initialize Google Maps client with the Google Maps API key
gmaps = googlemaps.Client(key='AIzaSyDZ4gKWNxnpJOUy9z86CxYFcLhe1yNPHug')

# List of properties for sale with additional data
properties_for_sale = [
    {"address": "715 Don Mills Rd 708, Toronto", "beds": 1, "baths": 1, "type": "Condo Apt Apartment", "price": 429900, "area": "600-699"},
    {"address": "735 Don Mills Rd 1401, Toronto", "beds": 1, "baths": 1, "type": "Condo Apt Apartment", "price": 439000, "area": "600-699"},
    {"address": "11 Thorncliffe Park Dr 705, Toronto", "beds": "1+1", "baths": 1, "type": "Condo Apt Apartment", "price": 439000, "area": "700-799"},
    {"address": "725 Don Mills Rd 306, Toronto", "beds": "2+1", "baths": 1, "type": "Condo Apt Apartment", "price": 449000, "area": "800-899"},
    {"address": "100 Leeward Glwy 1708, Toronto", "beds": 2, "baths": 1, "type": "Condo Apt Apartment", "price": 459800, "area": "900-999"},
    {"address": "10 Gateway Blvd 614, Toronto", "beds": "1+1", "baths": 1, "type": "Condo Apt Apartment", "price": 459900, "area": "900-999"},
    {"address": "160 Vanderhoof Ave 808, Toronto", "beds": 1, "baths": 1, "type": "Condo Apt Apartment", "price": 490000, "area": "0-499"},
    {"address": "725 Don Mills Rd 1206, Toronto", "beds": 2, "baths": 1, "type": "Condo Apt Apartment", "price": 495000, "area": "900-999"},
    {"address": "21 Overlea Blvd 1004, Toronto", "beds": 2, "baths": 1, "type": "Condo Apt Apartment", "price": 499000, "area": "900-999"},
    {"address": "715 Don Mills Rd 2002, Toronto", "beds": 2, "baths": 1, "type": "Condo Apt Apartment", "price": 499000, "area": "800-899"},
    {"address": "735 Don Mills Rd 1603, Toronto", "beds": 2, "baths": 1, "type": "Condo Apt Apartment", "price": 525000, "area": "900-999"},
    {"address": "100 Leeward Glwy 1801, Toronto", "beds": "2+1", "baths": 2, "type": "Condo Apt Apartment", "price": 529000, "area": "800-899"},
    {"address": "21 Overlea Blvd 511, Toronto", "beds": 2, "baths": 1, "type": "Condo Apt Apartment", "price": 555000, "area": "900-999"},
    {"address": "21 Overlea Blvd 1706, Toronto", "beds": 2, "baths": 2, "type": "Condo Apt Apartment", "price": 579000, "area": "900-999"},
    {"address": "25 Sunny Glen Way 312, Toronto", "beds": 3, "baths": 2, "type": "Condo Townhouse 2-Storey", "price": 599900, "area": "1000-1199"},
    {"address": "383 O'Connor Dr, Toronto", "beds": "2+2", "baths": 2, "type": "Detached Bungalow-Raised", "price": 1088000, "area": None},  # Detached Bungalow with no area specified
    {"address": "20B Leaside Park Dr B, Toronto", "beds": 3, "baths": 3, "type": "Condo Townhouse 3-Storey", "price": 1089000, "area": "1800-1999"},
    {"address": "461 Donlands Ave, Toronto", "beds": "3+1", "baths": 3, "type": "Detached 2-Storey", "price": 1299000, "area": None},
    {"address": "44 Parkview Hill Cres, Toronto", "beds": "3+1", "baths": 2, "type": "Detached 2-Storey", "price": 1620000, "area": None},
    {"address": "65 Derwyn Rd, Toronto", "beds": 4, "baths": 2, "type": "Detached 2-Storey", "price": 2299000, "area": "2000-2500"},
    {"address": "450 O'Connor Dr, Toronto", "beds": 5, "baths": 4, "type": "Detached 2-Storey", "price": 3499000, "area": "5000+"}
]

# Function to get latitude and longitude using Google Maps Geocoding API
def geocode_address(address):
    geocode_result = gmaps.geocode(address)
    if geocode_result:
        location = geocode_result[0]['geometry']['location']
        return location['lat'], location['lng']
    else:
        return None, None

# Create a list to store property data with coordinates
property_sale_data = []

for property in properties_for_sale:
    print(f"Geocoding address: {property['address']}")
    lat, lng = geocode_address(property['address'])
    property['latitude'] = lat
    property['longitude'] = lng
    property_sale_data.append(property)

# Create a DataFrame from the property data
housing_sale_df = pd.DataFrame(property_sale_data)

# Reorder the columns for better readability
housing_sale_df = housing_sale_df[['address', 'latitude', 'longitude', 'beds', 'baths', 'type', 'price', 'area']]

# Save the DataFrame to a CSV file
housing_sale_df.to_csv('../data/processed/housing_sale.csv', index=False)
print("Housing sale data saved to ../data/processed/housing_sale.csv")
# Out:
# Geocoding address: 715 Don Mills Rd 708, Toronto
# Geocoding address: 735 Don Mills Rd 1401, Toronto
# Geocoding address: 11 Thorncliffe Park Dr 705, Toronto
# Geocoding address: 725 Don Mills Rd 306, Toronto
# Geocoding address: 100 Leeward Glwy 1708, Toronto
# Geocoding address: 10 Gateway Blvd 614, Toronto
# Geocoding address: 160 Vanderhoof Ave 808, Toronto
# Geocoding address: 725 Don Mills Rd 1206, Toronto
# Geocoding address: 21 Overlea Blvd 1004, Toronto
# Geocoding address: 715 Don Mills Rd 2002, Toronto
# Geocoding address: 735 Don Mills Rd 1603, Toronto
# Geocoding address: 100 Leeward Glwy 1801, Toronto
# Geocoding address: 21 Overlea Blvd 511, Toronto
# Geocoding address: 21 Overlea Blvd 1706, Toronto
# Geocoding address: 25 Sunny Glen Way 312, Toronto
# Geocoding address: 383 O'Connor Dr, Toronto
# Geocoding address: 20B Leaside Park Dr B, Toronto
# Geocoding address: 461 Donlands Ave, Toronto
# Geocoding address: 44 Parkview Hill Cres, Toronto
# ...
